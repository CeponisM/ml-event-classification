# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("../data/training.csv")

# Basic info
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing values:\n", df.isna().sum())

# Show a few rows
df.head()
# Out:
# Shape: (250000, 33)
#
# Columns: ['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet', 'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality', 'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt', 'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt', 'Weight', 'Label']
#
# Missing values:
#  EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# ...

# %%
# Count of signal vs background
sns.countplot(data=df, x="Label")
plt.title("Signal vs Background Distribution")
plt.show()

# %%
# Example: Plot distribution of a few features
features = ["DER_mass_MMC", "DER_mass_transverse_met_lep", "DER_pt_h"]

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df, x=feature, hue="Label", bins=50, kde=False, stat="density", common_norm=False)
    plt.title(f"Feature Distribution: {feature}")
    plt.show()

# %%
(df == -999.0).sum().sort_values(ascending=False).head()
# Out:
# DER_mass_jet_jet          177457
# PRI_jet_subleading_phi    177457
# DER_prodeta_jet_jet       177457
# DER_deltaeta_jet_jet      177457
# DER_lep_eta_centrality    177457
# dtype: int64
